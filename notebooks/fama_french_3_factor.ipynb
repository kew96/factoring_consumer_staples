# %% [markdown]
# # Fama-French Three-Factor Model with Markowitz Optimization

# %%
import pandas as pd
import matplotlib.pyplot as plt

import sys; sys.path.insert(0, '..')
from src.features import fama_french

# %%
tfm = fama_french.ThreeFactorModel()

# %%
rets = tfm.max_sharpe_portfolios(2000, 2020)
# Out:
# Year:   0%|          | 0/21 [00:00<?, ?it/s]
# 2000:   0%|          | 0/4 [00:00<?, ?it/s]
# 2001:   0%|          | 0/4 [00:00<?, ?it/s]
# 2002:   0%|          | 0/4 [00:00<?, ?it/s]
# 2003:   0%|          | 0/4 [00:00<?, ?it/s]
# 2004:   0%|          | 0/4 [00:00<?, ?it/s]
# 2005:   0%|          | 0/4 [00:00<?, ?it/s]
# 2006:   0%|          | 0/4 [00:00<?, ?it/s]
# 2007:   0%|          | 0/4 [00:00<?, ?it/s]
# 2008:   0%|          | 0/4 [00:00<?, ?it/s]
# 2009:   0%|          | 0/4 [00:00<?, ?it/s]
# 2010:   0%|          | 0/4 [00:00<?, ?it/s]
# 2011:   0%|          | 0/4 [00:00<?, ?it/s]
# 2012:   0%|          | 0/4 [00:00<?, ?it/s]
# 2013:   0%|          | 0/4 [00:00<?, ?it/s]
# 2014:   0%|          | 0/4 [00:00<?, ?it/s]
# 2015:   0%|          | 0/4 [00:00<?, ?it/s]
# 2016:   0%|          | 0/4 [00:00<?, ?it/s]
# 2017:   0%|          | 0/4 [00:00<?, ?it/s]
# 2018:   0%|          | 0/4 [00:00<?, ?it/s]
# 2019:   0%|          | 0/4 [00:00<?, ?it/s]
# 2020:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
mean = rets.ret.mean()
std = rets.ret.std()
print(f'{mean} ({std}): \t ({mean-1.96*std}, {mean+1.96*std})')
# Out:
# 0.05876746145921528 (0.11537440772677225): 	 (-0.16736637768525833, 0.2849013006036889)

# %%
rets.sort_index().plot(figsize=(15, 10), grid=True, legend=False)

# %%
print(f'pre 2010:\t{rets.loc[:2010,].ret.std()}')
print(f'post 2010:\t{rets.loc[2010:].ret.std()}')
# Out:
# pre 2010:	0.11898536915097611
# post 2010:	0.10679174941231154
